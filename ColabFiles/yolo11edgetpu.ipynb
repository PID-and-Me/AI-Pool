# %% [markdown]
# <a href="https://colab.research.google.com/github/PID-and-Me/AI-Pool/blob/main/ColabFiles/yolo11edgetpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "protobuf>=4.21.6"
# !pip install ultralytics
# !pip install "onnx2tf>=1.17.5,<=1.26.3"
# !pip install onnx
# !pip install "sng4onnx>=1.0.1"
# !pip install "onnx-graphsurgeon>=0.3.26"
# !pip install "onnxslim>=0.1.31"
# !pip install tflite-support
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.9/932.9 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("yolov5nu.pt")

# Export the model to TFLite Edge TPU format
model.export(format="edgetpu",imgsz=192)  # creates 'yolo11n_full_integer_quant_edgetpu.tflite'
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.00GHz)
# YOLOv5n summary (fused): 84 layers, 2,649,200 parameters, 0 gradients, 7.7 GFLOPs
#
# PyTorch: starting from 'yolov5nu.pt' with input shape (1, 3, 192, 192) BCHW and output shape(s) (1, 84, 756) (5.3 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 2.8s, saved as 'yolov5nu.onnx' (10.2 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.26.3...
# Saved artifact at 'yolov5nu_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 192, 192, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 84, 756), dtype=tf.float32, name=None)
# Captures:
#   138940560801616: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
# ...

# %%
# !yolo predict model=/content/yolo11n.pt source='/1740065004321.jpg'
# Out:
# Ultralytics 8.3.87 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 /1740065004321.jpg: 480x640 2 persons, 2 books, 158.5ms
# Speed: 6.0ms preprocess, 158.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
